# %%
import pandas as pd
import pandas_profiling
import src.datajanitor as datajanitor
import numpy as np
import seaborn
import matplotlib.pyplot as plt


shopperDs = datajanitor.getDataset('shoppers')
shopperDs.fetchData()
shoppers = shopperDs.formatData()

# %%
shoppers.sample(5)
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 11930               0                 0.000000              1
# 8988                0                 0.000000              0
# 6166                6                60.366667              3
# 8872                4                95.750000             12
# 10673               7                98.172619              0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 11930                   36.50              40              1121.416667
# 8988                     0.00              21              1077.250000
# 6166                   189.30              12               304.700000
# 8872                   886.25             154              7838.556598
# 10673                    0.00              47              1889.953409
#
#        BounceRates  ExitRates  PageValues  SpecialDay  ... TrafficType_14  \
# 11930     0.000000   0.022195    0.000000         0.0  ...              0
# ...
